# %%
import pandas as pd

haireyecolor = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/HairEyeColor.csv')

pd.set_option("display.precision", 2)

haireyecolor.head()
# Out:
#    Unnamed: 0   Hair    Eye   Sex  Freq
# 0           1  Black  Brown  Male    32
# 1           2  Brown  Brown  Male    53
# 2           3    Red  Brown  Male    10
# 3           4  Blond  Brown  Male     3
# 4           5  Black   Blue  Male    11

# %%
haireyecolor.tail()
# Out:
#     Unnamed: 0   Hair    Eye     Sex  Freq
# 27          28  Blond  Hazel  Female     5
# 28          29  Black  Green  Female     2
# 29          30  Brown  Green  Female    14
# 30          31    Red  Green  Female     7
# 31          32  Blond  Green  Female     8

# %%
haireyecolor.columns = ['ID', 'Hair Color', 'Eye Color', 'Sex', 'Frequency Occurs']
haireyecolor.head()
# Out:
#    ID Hair Color Eye Color   Sex  Frequency Occurs
# 0   1      Black     Brown  Male                32
# 1   2      Brown     Brown  Male                53
# 2   3        Red     Brown  Male                10
# 3   4      Blond     Brown  Male                 3
# 4   5      Black      Blue  Male                11

# %%
haireyecolor.describe()
# Out:
#           ID  Frequency Occurs
# count  32.00             32.00
# mean   16.50             18.50
# std     9.38             18.24
# min     1.00              2.00
# 25%     8.75              7.00
# 50%    16.50             10.00
# 75%    24.25             29.25
# max    32.00             66.00

# %%
# %matplotlib inline

haireyecolor_histogram = haireyecolor.hist()

# %% [markdown]
# #### Written by Lindsey Sullivan
